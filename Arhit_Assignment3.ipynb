# %% [markdown]
# # Applied Data Science Assignment - 3
# ### Name: Arhit Bose Tagore
# ### Registration Number: 20BCE2150
# ### Email ID: arhitbose.tagore2020@vitstudent.ac.in
# ### VIT Vellore

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
% matplotlib inline
import warnings
warnings.filterwarnings('ignore')
# Out:
# UsageError: Line magic function `%` not found.

# %% [markdown]
# 1. Download the dataset: Dataset

# %% [markdown]
# 2. Load the dataset.

# %%
data = pd.read_csv("Housing.csv")
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement
# 0  13300000  7420         4          2        3      yes        no       no  \
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no             yes        2        furnished
# 1              no             yes        3        furnished
# 2              no              no        2   semi-furnished
# 3              no             yes        3        furnished
# 4              no             yes        2        furnished

# %% [markdown]
# 3. Perform Below Visualizations.

# %% [markdown]
# ● Univariate Analysis

# %%
# Histogram of Price
sns.histplot(data['price'], bins=10)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Histogram of Price')
plt.show()

# %%
# Histogram of Area
sns.histplot(data['area'], bins=10)
plt.xlabel('Area')
plt.ylabel('Frequency')
plt.title('Histogram of Area')
plt.show()

# %%
# Bar plot of Bedrooms
plt.bar(data['bedrooms'].value_counts().index, data['bedrooms'].value_counts().values)
plt.xlabel('Bedrooms')
plt.ylabel('Count')
plt.title('Bar Plot of Bedrooms')
plt.show()

# %%
# Bar plot of Bathrooms
plt.bar(data['bathrooms'].value_counts().index, data['bathrooms'].value_counts().values)
plt.xlabel('Bathrooms')
plt.ylabel('Count')
plt.title('Bar Plot of Bathrooms')
plt.show()

# %%
# Bar plot of Stories
plt.bar(data['stories'].value_counts().index, data['stories'].value_counts().values)
plt.xlabel('Stories')
plt.ylabel('Count')
plt.title('Bar Plot of Stories')
plt.show()

# %%
# Bar plot of Mainroad
plt.bar(data['mainroad'].value_counts().index, data['mainroad'].value_counts().values)
plt.xlabel('Mainroad')
plt.ylabel('Count')
plt.title('Bar Plot of Mainroad')
plt.show()

# %%
# Bar plot of Guestroom
plt.bar(data['guestroom'].value_counts().index, data['guestroom'].value_counts().values)
plt.xlabel('Guestroom')
plt.ylabel('Count')
plt.title('Bar Plot of Guestroom')
plt.show()

# %%
# Bar plot of Basement
plt.bar(data['basement'].value_counts().index, data['basement'].value_counts().values)
plt.xlabel('Basement')
plt.ylabel('Count')
plt.title('Bar Plot of Basement')
plt.show()

# %%
# Bar plot of Hot Water Heating
plt.bar(data['hotwaterheating'].value_counts().index, data['hotwaterheating'].value_counts().values)
plt.xlabel('Hot Water Heating')
plt.ylabel('Count')
plt.title('Bar Plot of Hot Water Heating')
plt.show()

# %%
# Bar plot of Air Conditioning
plt.bar(data['airconditioning'].value_counts().index, data['airconditioning'].value_counts().values)
plt.xlabel('Air Conditioning')
plt.ylabel('Count')
plt.title('Bar Plot of Air Conditioning')
plt.show()

# %%
# Bar plot of Parking
plt.bar(data['parking'].value_counts().index, data['parking'].value_counts().values)
plt.xlabel('Parking')
plt.ylabel('Count')
plt.title('Bar Plot of Parking')
plt.show()

# %%
# Bar plot of Furnishing Status
plt.bar(data['furnishingstatus'].value_counts().index, data['furnishingstatus'].value_counts().values)
plt.xlabel('Furnishing Status')
plt.ylabel('Count')
plt.title('Bar Plot of Furnishing Status')
plt.show()

# %% [markdown]
# ● Bivariate Analysis

# %%
# Scatter plot of Price vs. Area
sns.scatterplot(data=data, x='area', y='price')
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Scatter plot of Price vs. Area')
plt.show()

# %%
# Box plot of Price vs. Bedrooms
sns.boxplot(data=data, x='bedrooms', y='price')
plt.xlabel('Bedrooms')
plt.ylabel('Price')
plt.title('Box plot of Price vs. Bedrooms')
plt.show()

# %%
# Box plot of Price vs. Bathrooms
sns.boxplot(data=data, x='bathrooms', y='price')
plt.xlabel('Bathrooms')
plt.ylabel('Price')
plt.title('Box plot of Price vs. Bathrooms')
plt.show()

# %%
# Box plot of Price vs. Furnishing Status
sns.boxplot(data=data, x='furnishingstatus', y='price')
plt.xlabel('Furnishing Status')
plt.ylabel('Price')
plt.title('Box plot of Price vs. Furnishing Status')
plt.show()

# %%
# Box plot of Price vs. Air Conditioning
sns.boxplot(data=data, x='airconditioning', y='price')
plt.xlabel('Air Conditioning')
plt.ylabel('Price')
plt.title('Box plot of Price vs. Air Conditioning')
plt.show()

# %%
# Box plot of Price vs. Parking
sns.boxplot(data=data, x='parking', y='price')
plt.xlabel('Parking')
plt.ylabel('Price')
plt.title('Box plot of Price vs. Parking')
plt.show()

# %%
# Bar plot of Bedrooms vs. Bathrooms
sns.countplot(data=data, x='bedrooms', hue='bathrooms')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
plt.title('Bar plot of Bedrooms vs. Bathrooms')
plt.legend(title='Bathrooms')
plt.show()

# %%
# Bar plot of Furnishing Status vs. Air Conditioning
sns.countplot(data=data, x='furnishingstatus', hue='airconditioning')
plt.xlabel('Furnishing Status')
plt.ylabel('Count')
plt.title('Bar plot of Furnishing Status vs. Air Conditioning')
plt.legend(title='Air Conditioning')
plt.show()

# %%
# Violin plot of Price vs. Bedrooms
sns.violinplot(data=data, x='bedrooms', y='price')
plt.xlabel('Bedrooms')
plt.ylabel('Price')
plt.title('Violin plot of Price vs. Bedrooms')
plt.show()

# %%
# Violin plot of Price vs. Furnishing Status
sns.violinplot(data=data, x='furnishingstatus', y='price')
plt.xlabel('Furnishing Status')
plt.ylabel('Price')
plt.title('Violin plot of Price vs. Furnishing Status')
plt.show()

# %%
# Swarm plot of Price vs. Furnishing Status
sns.swarmplot(data=data, x='furnishingstatus', y='price')
plt.xlabel('Furnishing Status')
plt.ylabel('Price')
plt.title('Swarm plot of Price vs. Furnishing Status')
plt.show()
# Out:
# /Users/arhit/Library/Python/3.9/lib/python/site-packages/seaborn/categorical.py:3544: UserWarning: 6.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# Scatter plot matrix
sns.pairplot(data, vars=['price', 'area', 'bedrooms', 'bathrooms'])
plt.title('Scatter plot matrix')
plt.show()

# %% [markdown]
# ● Multivariate Analysis

# %%
# Pairplot
sns.pairplot(data, vars=['price', 'area', 'bedrooms', 'bathrooms'])
plt.title('Pairplot')
plt.show()

# %%
# Violin plot of Price vs. Bedrooms
sns.violinplot(data=data, x='bedrooms', y='price')
plt.xlabel('Bedrooms')
plt.ylabel('Price')
plt.title('Violin plot of Price vs. Bedrooms')
plt.show()

# %%
# Violin plot of Price vs. Furnishing Status
sns.violinplot(data=data, x='furnishingstatus', y='price')
plt.xlabel('Furnishing Status')
plt.ylabel('Price')
plt.title('Violin plot of Price vs. Furnishing Status')
plt.show()

# %%
# Swarm plot of Price vs. Furnishing Status
sns.swarmplot(data=data, x='furnishingstatus', y='price')
plt.xlabel('Furnishing Status')
plt.ylabel('Price')
plt.title('Swarm plot of Price vs. Furnishing Status')
plt.show()
# Out:
# /Users/arhit/Library/Python/3.9/lib/python/site-packages/seaborn/categorical.py:3544: UserWarning: 6.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# 4. Perform descriptive statistics on the dataset.

# %%
# Perform descriptive statistics
descriptive_stats = data.describe()
descriptive_stats
# Out:
#               price          area    bedrooms   bathrooms     stories
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000  \
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %% [markdown]
# ### Analysis of descriptive statistics
# 1. Price

# %%
# Mean of Price
mean_price = data['price'].mean()
print('Mean of Price:', mean_price)

# Median of Price
median_price = data['price'].median()
print('Median of Price:', median_price)

# Mode of Price
mode_price = data['price'].mode()
print('Mode of Price:', mode_price)

# Standard Deviation of Price
std_price = data['price'].std()
print('Standard Deviation of Price:', std_price)

# Variance of Price
var_price = data['price'].var()
print('Variance of Price:', var_price)

# Range of Price
range_price = data['price'].max() - data['price'].min()
print('Range of Price:', range_price)

# Interquartile Range of Price
iqr_price = data['price'].quantile(0.75) - data['price'].quantile(0.25)
print('Interquartile Range of Price:', iqr_price)


# Skewness of Price
skew_price = data['price'].skew()
print('Skewness of Price:', skew_price)

# Kurtosis of Price
kurt_price = data['price'].kurt()
print('Kurtosis of Price:', kurt_price)
# Out:
# Mean of Price: 4766729.247706422
# Median of Price: 4340000.0
# Mode of Price: 0    3500000
# 1    4200000
# Name: price, dtype: int64
# Standard Deviation of Price: 1870439.6156573922
# Variance of Price: 3498544355820.573
# Range of Price: 11550000
# Interquartile Range of Price: 2310000.0
# Skewness of Price: 1.2122388370279802
# Kurtosis of Price: 1.9601302314151994

# %% [markdown]
# 2. Area

# %%
# Mean of Area
mean_area = data['area'].mean()
print('Mean of Area:', mean_area)

# Median of Area
median_area = data['area'].median()
print('Median of Area:', median_area)

# Mode of Area
mode_area = data['area'].mode()
print('Mode of Area:', mode_area)

# Standard Deviation of Area
std_area = data['area'].std()
print('Standard Deviation of Area:', std_area)

# Variance of Area
var_area = data['area'].var()
print('Variance of Area:', var_area)

# Range of Area
range_area = data['area'].max() - data['area'].min()
print('Range of Area:', range_area)

# Interquartile Range of Area
iqr_area = data['area'].quantile(0.75) - data['area'].quantile(0.25)
print('Interquartile Range of Area:', iqr_area)
# Out:
# Mean of Area: 5150.54128440367
# Median of Area: 4600.0
# Mode of Area: 0    6000
# Name: area, dtype: int64
# Standard Deviation of Area: 2170.141022508803
# Variance of Area: 4709512.057575554
# Range of Area: 14550
# Interquartile Range of Area: 2760.0

# %%
# Impute missing values for all numeric variables
data['price'] = data['price'].fillna(data['price'].mean())
data['area'] = data['area'].fillna(data['area'].mean())
data['bedrooms'] = data['bedrooms'].fillna(data['bedrooms'].mean())
data['bathrooms'] = data['bathrooms'].fillna(data['bathrooms'].mean())
data['stories'] = data['stories'].fillna(data['stories'].mean())
data['parking'] = data['parking'].fillna(data['parking'].mean())

# Impute missing values for categorical variables
data['mainroad'] = data['mainroad'].fillna(data['mainroad'].mode()[0])
data['guestroom'] = data['guestroom'].fillna(data['guestroom'].mode()[0])
data['basement'] = data['basement'].fillna(data['basement'].mode()[0])
data['hotwaterheating'] = data['hotwaterheating'].fillna(data['hotwaterheating'].mode()[0])
data['airconditioning'] = data['airconditioning'].fillna(data['airconditioning'].mode()[0])
data['furnishingstatus'] = data['furnishingstatus'].fillna(data['furnishingstatus'].mode()[0])

# Check for missing values
data.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# furnishingstatus    0
# dtype: int64

# %%
# Find Outliers and replace them 
# Boxplot of Price
sns.boxplot(data=data, x='price')
plt.xlabel('Price')
plt.title('Boxplot of Price')
plt.show()

# %%
numeric_columns = data.select_dtypes(include=['float64', 'int64'])

# %%
# Calculate skewness and kurtosis
skewness = numeric_columns.skew()
kurtosis = numeric_columns.kurtosis()

# Define a function to replace outliers with the median value
def replace_outliers(column):
    median = column.median()
    std = column.std()
    outliers = (column - median).abs() > 3 * std
    column[outliers] = median
    return column
    
# Replace outliers in each numeric column with the median value
for column in numeric_columns:
    numeric_columns[column] = replace_outliers(numeric_columns[column])

# Update the original DataFrame with the replaced values
data.update(numeric_columns)

# Verify the replaced outliers
replaced_outliers = pd.DataFrame({'Skewness': numeric_columns.skew(), 'Kurtosis': numeric_columns.kurtosis()})
print("Replaced Outliers:")
print(replaced_outliers)
# Out:
# Replaced Outliers:
#            Skewness  Kurtosis
# price      0.753439  0.121488
# area       0.597173 -0.290998
# bedrooms   0.309783  0.052185
# bathrooms  1.195164 -0.573701
# stories    1.082088  0.679404
# parking    0.768436 -0.992767

# %%
# Encode categorical variables
categorical_columns = ['mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'furnishingstatus']
encoded_data = pd.get_dummies(data, columns=categorical_columns, drop_first=True)

# %%
X = encoded_data.drop('price', axis=1)  # Independent variables
y = encoded_data['price']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Lasso, Ridge
from sklearn.metrics import mean_squared_error, r2_score

# %%
linear_reg = LinearRegression()
decision_tree_reg = DecisionTreeRegressor()
random_forest_reg = RandomForestRegressor()
lasso_reg = Lasso()
ridge_reg = Ridge()

models = [linear_reg, decision_tree_reg, random_forest_reg, lasso_reg, ridge_reg]

# %%
# Define a function to calculate the RMSE and R2 score
def calculate_metrics(model):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    return rmse, r2

# %%
# Train and test each model
for model in models:
    rmse, r2 = calculate_metrics(model)
    print(type(model).__name__)
    print('RMSE:', rmse)
    print('R2 Score:', r2)
    print()
# Out:
# LinearRegression
# RMSE: 1234699.5467902534
# R2 Score: 0.4875608933696991
#
# DecisionTreeRegressor
# RMSE: 1529424.6880624904
# R2 Score: 0.21372244131380935
#
# RandomForestRegressor
# RMSE: 1271988.871268967
# R2 Score: 0.4561410107513375
#
# Lasso
# RMSE: 1234699.7354005182
# R2 Score: 0.48756073681131484
#
# Ridge
# RMSE: 1234469.1370850408
# R2 Score: 0.48775213005894835

# %%
# Test each model with cross-validation
from sklearn.model_selection import cross_val_score

for model in models:
    scores = cross_val_score(model, X_scaled, y, cv=5, scoring='r2')
    print(type(model).__name__)
    print('R2 Scores:', scores)
    print('Mean R2 Score:', np.mean(scores))
    print()
# Out:
# LinearRegression
# R2 Scores: [ -1.92278575  -3.37722586 -13.55210161 -15.94574187  -7.78174455]
# Mean R2 Score: -8.515919931276489
#
# DecisionTreeRegressor
# R2 Scores: [ -2.47356303 -16.96559104 -41.01962521 -58.66057249  -9.61707337]
# Mean R2 Score: -25.747285029272984
#
# RandomForestRegressor
# R2 Scores: [ -2.38473076  -4.78539565 -18.62334879 -18.19148654 -10.83597736]
# Mean R2 Score: -10.96418781815613
#
# Lasso
# R2 Scores: [ -1.92279534  -3.37722147 -13.55205554 -15.94570484  -7.781782  ]
# Mean R2 Score: -8.515911838183186
#
# Ridge
# R2 Scores: [ -1.92741285  -3.37114754 -13.51986375 -15.9334342   -7.79752202]
# Mean R2 Score: -8.509876072990469

# %%
# plot the RMSE and R2 score for each model
rmse_scores = []
r2_scores = []
for model in models:
    rmse, r2 = calculate_metrics(model)
    rmse_scores.append(rmse)
    r2_scores.append(r2)

plt.figure(figsize=(10, 5))
plt.title('RMSE Score Comparison')
plt.xlabel('Model')
plt.ylabel('RMSE Score')
plt.bar([type(model).__name__ for model in models], rmse_scores)
plt.show()

plt.figure(figsize=(10, 5))
plt.title('R2 Score Comparison')
plt.xlabel('Model')
plt.ylabel('R2 Score')
plt.bar([type(model).__name__ for model in models], r2_scores)
plt.show()
