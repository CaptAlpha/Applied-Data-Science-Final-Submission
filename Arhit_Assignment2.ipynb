# %% [markdown]
# # Applied Data Science Assignment - 2
# ### Name: Arhit Bose Tagore
# ### Registration Number: 20BCE2150
# ### Email ID: arhitbose.tagore2020@vitstudent.ac.in
# ### VIT Vellore

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
% matplotlib inline
import warnings
warnings.filterwarnings('ignore')
# Out:
# UsageError: Line magic function `%` not found.

# %% [markdown]
# 1. Download the dataset: Dataset

# %% [markdown]
# 2. Load the dataset.

# %%
df = pd.read_csv("titanic.csv")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# 3. Perform Below Visualizations.

# %% [markdown]
# ● Univariate Analysis

# %%
# Univariate Analysis
# 1. Histogram

plot = sns.distplot(df['age'].dropna(), kde=False, bins=10)
plot.set_title("Histogram of Age")
plot.set_ylabel("Frequency")
plot.set_xlabel("Age")
plt.show()
# Out:
# /var/folders/q8/f9vrzyc51lq47hzwq5f394g00000gp/T/ipykernel_70125/2325267440.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   plot = sns.distplot(df['age'].dropna(), kde=False, bins=10)

# %%
# 2. Boxplot

plot = sns.boxplot(x=df['age'])
plot.set_title("Boxplot of Age")
plot.set_xlabel("Age")
plt.show()

# %% [markdown]
# ● Bi - Variate Analysis

# %%
# Bivariate Analysis
# Scatter plot of Fare vs Age colored by Survived
sns.scatterplot(data=df, x="fare", y="age", hue="survived")
plt.xlabel("Fare")
plt.ylabel("Age")
plt.title("Fare vs Age (Colored by Survived)")
plt.show()

# %%
# Box plot of Fare by Sex
sns.boxplot(data=df, x="sex", y="fare")
plt.xlabel("Sex")
plt.ylabel("Fare")
plt.title("Fare by Sex")
plt.show()

# %%
# Violin plot of Age by Pclass
sns.violinplot(data=df, x="pclass", y="age")
plt.xlabel("Pclass")
plt.ylabel("Age")
plt.title("Age by Pclass")
plt.show()

# %%
# Bar plot of Survived by Embark_town
sns.barplot(data=df, x="embark_town", y="survived")
plt.xlabel("Embark Town")
plt.ylabel("Survived")
plt.title("Survived by Embark Town")
plt.show()

# %%
# Count plot of Survived by Who
sns.countplot(data=df, x="who", hue="survived")
plt.xlabel("Who")
plt.ylabel("Count")
plt.title("Survived by Who")
plt.show()

# %% [markdown]
# ● Multi - Variate Analysis

# %%
# Heatmap of correlation matrix
correlation = df[["survived", "age", "fare", "pclass", "sibsp", "parch"]].corr()
sns.heatmap(data=correlation, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
# Pair plot of select variables colored by Survived
sns.pairplot(data=df, vars=["age", "fare", "pclass"], hue="survived")
plt.title("Pair Plot of Age, Fare, and Pclass (Colored by Survived)")
plt.show()

# %%
# Scatter plot matrix of select variables
sns.set(style="ticks")
sns.pairplot(data=df, vars=["age", "fare", "pclass"], hue="survived", markers=["o", "s"])
plt.title("Scatter Plot Matrix of Age, Fare, and Pclass (Colored by Survived)")
plt.show()

# %%
# Swarm plot of Age by Pclass colored by Survived
sns.swarmplot(data=df, x="pclass", y="age", hue="survived")
plt.xlabel("Pclass")
plt.ylabel("Age")
plt.title("Age by Pclass (Colored by Survived)")
plt.show()
# Out:
# /Users/arhit/Library/Python/3.9/lib/python/site-packages/seaborn/categorical.py:3544: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# Violin plot of Age by Pclass and Sex colored by Survived
sns.violinplot(data=df, x="pclass", y="age", hue="sex", split=True, inner="stick", palette="Set2")
plt.xlabel("Pclass")
plt.ylabel("Age")
plt.title("Age by Pclass and Sex (Colored by Survived)")
plt.show()

# %% [markdown]
# 4. Perform descriptive statistics on the dataset.

# %%
descriptive_stats = df.describe()
descriptive_stats
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ### Analysis of descriptive statistics
# #### 1. Age

# %%
# Mean of Age
mean_age = descriptive_stats.loc["mean", "age"]
print("Mean of Age: ", mean_age)

# Median of Age
median_age = descriptive_stats.loc["50%", "age"]
print("Median of Age: ", median_age)

# Mode of Age
mode_age = df["age"].mode()
print("Mode of Age: ", mode_age)

# Standard Deviation of Age
std_age = descriptive_stats.loc["std", "age"]
print("Standard Deviation of Age: ", std_age)

# Variance of Age
var_age = descriptive_stats.loc["std", "age"] ** 2
print("Variance of Age: ", var_age)

# Range of Age
range_age = df["age"].max() - df["age"].min()
print("Range of Age: ", range_age)

# Interquartile Range of Age
iqr_age = descriptive_stats.loc["75%", "age"] - descriptive_stats.loc["25%", "age"]
print("Interquartile Range of Age: ", iqr_age)

# Skewness of Age
skew_age = df["age"].skew()
print("Skewness of Age: ", skew_age)

# Kurtosis of Age
kurt_age = df["age"].kurt()
print("Kurtosis of Age: ", kurt_age)
# Out:
# Mean of Age:  29.69911764705882
# Median of Age:  28.0
# Mode of Age:  0    24.0
# Name: age, dtype: float64
# Standard Deviation of Age:  14.526497332334042
# Variance of Age:  211.01912474630805
# Range of Age:  79.58
# Interquartile Range of Age:  17.875
# Skewness of Age:  0.38910778230082704
# Kurtosis of Age:  0.17827415364210353

# %% [markdown]
# #### Fare

# %%
# Mean of Fare
mean_fare = descriptive_stats.loc["mean", "fare"]
print("Mean of Fare: ", mean_fare)

# Median of Fare
median_fare = descriptive_stats.loc["50%", "fare"]
print("Median of Fare: ", median_fare)

# Mode of Fare
mode_fare = df["fare"].mode()
print("Mode of Fare: ", mode_fare)

# Standard Deviation of Fare
std_fare = descriptive_stats.loc["std", "fare"]
print("Standard Deviation of Fare: ", std_fare)

# Variance of Fare
var_fare = descriptive_stats.loc["std", "fare"] ** 2
print("Variance of Fare: ", var_fare)

# Range of Fare
range_fare = df["fare"].max() - df["fare"].min()
print("Range of Fare: ", range_fare)

# Interquartile Range of Fare
iqr_fare = descriptive_stats.loc["75%", "fare"] - descriptive_stats.loc["25%", "fare"]
print("Interquartile Range of Fare: ", iqr_fare)

# Skewness of Fare
skew_fare = df["fare"].skew()
print("Skewness of Fare: ", skew_fare)

# Kurtosis of Fare
kurt_fare = df["fare"].kurt()
print("Kurtosis of Fare: ", kurt_fare)
# Out:
# Mean of Fare:  32.204207968574636
# Median of Fare:  14.4542
# Mode of Fare:  0    8.05
# Name: fare, dtype: float64
# Standard Deviation of Fare:  49.6934285971809
# Variance of Fare:  2469.436845743116
# Range of Fare:  512.3292
# Interquartile Range of Fare:  23.0896
# Skewness of Fare:  4.787316519674893
# Kurtosis of Fare:  33.39814088089868

# %% [markdown]
# #### PClass

# %%
# Mean of Pclass
mean_pclass = descriptive_stats.loc["mean", "pclass"]
print("Mean of Pclass: ", mean_pclass)

# Median of Pclass
median_pclass = descriptive_stats.loc["50%", "pclass"]
print("Median of Pclass: ", median_pclass)

# Mode of Pclass
mode_pclass = df["pclass"].mode()
print("Mode of Pclass: ", mode_pclass)

# Standard Deviation of Pclass
std_pclass = descriptive_stats.loc["std", "pclass"]
print("Standard Deviation of Pclass: ", std_pclass)

# Variance of Pclass
var_pclass = descriptive_stats.loc["std", "pclass"] ** 2
print("Variance of Pclass: ", var_pclass)

# Range of Pclass
range_pclass = df["pclass"].max() - df["pclass"].min()
print("Range of Pclass: ", range_pclass)

# Interquartile Range of Pclass
iqr_pclass = descriptive_stats.loc["75%", "pclass"] - descriptive_stats.loc["25%", "pclass"]

# Skewness of Pclass
skew_pclass = df["pclass"].skew()
print("Skewness of Pclass: ", skew_pclass)

# Kurtosis of Pclass
kurt_pclass = df["pclass"].kurt()
print("Kurtosis of Pclass: ", kurt_pclass)
# Out:
# Mean of Pclass:  2.308641975308642
# Median of Pclass:  3.0
# Mode of Pclass:  0    3
# Name: pclass, dtype: int64
# Standard Deviation of Pclass:  0.836071240977049
# Variance of Pclass:  0.6990151199889028
# Range of Pclass:  2
# Skewness of Pclass:  -0.6305479068752845
# Kurtosis of Pclass:  -1.2800149715782825

# %% [markdown]
# 5. Handle the Missing values.

# %%
# Example: Check missing values
missing_values = df.isnull().sum()
missing_values
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# Impute missing values for all numeric variables
df["age"] = df["age"].fillna(df["age"].mean())
df["embarked"] = df["embarked"].fillna(df["embarked"].mode()[0])
df["deck"] = df["deck"].fillna(df["deck"].mode()[0])
df["embark_town"] = df["embark_town"].fillna(df["embark_town"].mode()[0])

# Check missing values
missing_values = df.isnull().sum()
missing_values
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True    C  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False    C  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True    C  Southampton    no   True

# %% [markdown]
# 6. Find the outliers and replace the outliers

# %%
numeric_columns = df.select_dtypes(include=['float64', 'int64'])

# %%
# Create a box plot for each numeric column
plt.figure(figsize=(10, 6))
sns.boxplot(data=numeric_columns)
plt.title("Box Plot of Numeric Columns")
plt.xticks(rotation=45)
plt.show()

# %%
# Calculate skewness and kurtosis
skewness = numeric_columns.skew()
kurtosis = numeric_columns.kurtosis()

# Define a function to replace outliers with the median value
def replace_outliers(column):
    median = column.median()
    std = column.std()
    outliers = (column - median).abs() > 3 * std
    column[outliers] = median
    return column
    
# Replace outliers in each numeric column with the median value
for column in numeric_columns:
    numeric_columns[column] = replace_outliers(numeric_columns[column])

# Update the original DataFrame with the replaced values
df.update(numeric_columns)

# Verify the replaced outliers
replaced_outliers = pd.DataFrame({'Skewness': numeric_columns.skew(), 'Kurtosis': numeric_columns.kurtosis()})
print("Replaced Outliers:")
print(replaced_outliers)
# Out:
# Replaced Outliers:
#           Skewness  Kurtosis
# survived  0.478523 -1.775005
# pclass   -0.630548 -1.280015
# age       0.253480  0.628880
# sibsp     2.021043  4.390218
# parch     1.826457  1.946121
# fare      2.248313  5.263448
# /var/folders/q8/f9vrzyc51lq47hzwq5f394g00000gp/T/ipykernel_70125/3670312167.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[outliers] = median
# /var/folders/q8/f9vrzyc51lq47hzwq5f394g00000gp/T/ipykernel_70125/3670312167.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[outliers] = median
# ...

# %% [markdown]
# 7. Check for Categorical columns and perform encoding.

# %%
# Check categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns
print(categorical_cols)
# Out:
# Index(['sex', 'embarked', 'class', 'who', 'deck', 'embark_town', 'alive'], dtype='object')

# %%
# use the value_counts() function to display the unique values for each categorical feature
for column in categorical_cols:
    print(df[column].value_counts())
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64
# embarked
# S    646
# C    168
# Q     77
# Name: count, dtype: int64
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64
# who
# man      537
# woman    271
# child     83
# Name: count, dtype: int64
# deck
# C    747
# B     47
# D     33
# E     32
# A     15
# F     13
# G      4
# Name: count, dtype: int64
# embark_town
# Southampton    646
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64
# alive
# no     549
# yes    342
# Name: count, dtype: int64

# %%
# Use dummy variables to convert categorical features to numeric features

for column in categorical_cols:
    df = pd.concat([df, pd.get_dummies(df[column], prefix=column)], axis=1)
    df.drop(column, axis=1, inplace=True)

df.head()

# Replace True and False with 1 and 0
df = df.replace(True, 1)
df = df.replace(False, 0)

df.head()
# Out:
#    survived  pclass   age  sibsp  parch     fare  adult_male  alone
# 0         0       3  22.0      1      0   7.2500           1      0  \
# 1         1       1  38.0      1      0  71.2833           0      0
# 2         1       3  26.0      0      0   7.9250           0      1
# 3         1       1  35.0      1      0  53.1000           0      0
# 4         0       3  35.0      0      0   8.0500           1      1
#
#    sex_female  sex_male  ...  deck_C  deck_D  deck_E  deck_F  deck_G
# 0           0         1  ...       1       0       0       0       0  \
# 1           1         0  ...       1       0       0       0       0
# 2           1         0  ...       1       0       0       0       0
# 3           1         0  ...       1       0       0       0       0
# 4           0         1  ...       1       0       0       0       0
#
#    embark_town_Cherbourg  embark_town_Queenstown  embark_town_Southampton
# ...

# %% [markdown]
# 8. Split the data into dependent and independent variables.

# %%
X = df.drop('survived', axis=1)  # Independent variables
y = df['survived']  # Dependent variable

# %% [markdown]
# 9. Scale the independent variables

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# 10. Split the data into training and testing

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=123)

# %%
X_train.shape, X_test.shape
# Out:
# ((712, 30), (179, 30))

# %%
X_test.shape, y_test.shape
# Out:
# ((179, 30), (179,))

# %%
# Display the first five rows of the training sets
X_train[:5]
# Out:
# array([[-1.56610693, -1.07562624, -0.55649743,  1.09573704,  1.13237776,
#         -1.2316449 , -1.2316449 ,  1.35557354, -1.35557354,  2.0745051 ,
#         -0.30756234, -1.62380254,  1.76776695, -0.51015154, -1.10792599,
#         -0.32050393, -1.2316449 ,  1.51255508, -0.13085598,  4.23762278,
#         -2.27760839, -0.19611614, -0.19300938, -0.12168146, -0.06715343,
#          2.0745051 , -0.30756234, -1.62380254, -1.2669898 ,  1.2669898 ],
#        [ 0.82737724,  0.13167814, -0.55649743, -0.49692479, -0.64187276,
#          0.81192233,  0.81192233, -0.73769513,  0.73769513, -0.48204268,
#          3.25137334, -1.62380254, -0.56568542, -0.51015154,  0.90258736,
#         -0.32050393,  0.81192233, -0.66113295, -0.13085598, -0.23598136,
#          0.43905704, -0.19611614, -0.19300938, -0.12168146, -0.06715343,
#         -0.48204268,  3.25137334, -1.62380254,  0.78927234, -0.78927234],
#        [ 0.82737724,  1.29873904, -0.55649743, -0.49692479, -0.66041739,
# ...
